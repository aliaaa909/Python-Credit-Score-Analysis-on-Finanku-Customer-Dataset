# %% [markdown]
# #**PROBLEM STATEMENT**
#
# ingin memprediksi orang-orang yang berpotensi telat bayar kartu kredit finanku untuk dapat menentukan strategi yag sesuai untuk menghadapinya.
# ---

# %% [markdown]
# #**Objective**
#
# Membuat sebuah model yang dapat memprediksi setidaknya 60% dari pelanggan yang akan mengalami telat bayar kartu kredit (Accuracy dan Recall > 60%).

# %% [markdown]
# #**Variable**
#
# Customer ID: unique ID customer.
#
# Branch: lokasi cabang nasabah terdaftar.
#
# City: lokasi kota nasabah terdaftar.
#
# Age: umur nasabah pada periode observasi.
#
# Avg. Annual Income: rata-rata penghasilan nasabah dalam satu tahun.
#
# Balance (Q1-Q4): saldo mengendap yang dimiliki nasabah di akhir kuartal.
#
# Num of Product (Q1-Q4): jumlah kepemilikan produk nasabah yang dimiliki di akhir kuartal.
#
# HasCrCard (Q1-Q4): status kepemilikan produk kartu kredit nasabah di akhir kuartal.
#
# Active Member (Q1-Q4): status keaktifan nasabah.
#
# Unpaid tagging: status nasabah gagal bayar.

# %% [markdown]
# #**Experiment**
#
# **Periode tinjauan:**
#
# Nasabah di-review selama satu tahun terakhir.
#
# Nasabah di-review selama 6 bulan terakhir.
#
# **Penyesuaian variabel:**
#
# Balance dilihat dari rata-rata selama horizon waktu dan dilihat perubahan pada akhir tinjauan dan awal tinjauan.
#
# Melihat kepemilikan jumlah produk dari rata-rata, maksimum, dan minimum pada periode tinjauan.
#
# Status keaktifan nasabah dilihat dalam bentuk bulan.

# %% [markdown]
# #**Import Package**

# %%
# !pip install jcopml #jika tidak ada modul/package jcopml

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, classification_report, make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from jcopml.feature_importance import mean_score_decrease
# Out:
# Requirement already satisfied: jcopml in /usr/local/lib/python3.11/dist-packages (1.2.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from jcopml) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from jcopml) (1.13.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from jcopml) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from jcopml) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from jcopml) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from jcopml) (0.13.2)
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.11/dist-packages (from jcopml) (0.10.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from jcopml) (7.7.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from jcopml) (0.14.4)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.11/dist-packages (from jcopml) (1.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jcopml) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jcopml) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jcopml) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jcopml) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jcopml) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->jcopml) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->jcopml) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->jcopml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->jcopml) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->jcopml) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->jcopml) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->jcopml) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->jcopml) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->jcopml) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->jcopml) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->jcopml) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->jcopml) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->jcopml) (3.5.0)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize->jcopml) (25.1.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->jcopml) (1.0.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->jcopml) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->jcopml) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->jcopml) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->jcopml) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->jcopml) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->jcopml) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->jcopml) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->jcopml) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->jcopml) (4.9.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from pyaml>=16.9->scikit-optimize->jcopml) (6.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->jcopml) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->jcopml) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->jcopml) (0.8.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (3.1.5)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->jcopml) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->jcopml) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (3.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.22.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.8.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.3.1)

# %% [markdown]
# #**Data for Prediction**

# %%
path_1 = "https://raw.githubusercontent.com/brainspopper/dataset/main/FinanKu%20Data%20All.csv"
path_2 = "https://raw.githubusercontent.com/brainspopper/dataset/main/FinanKu%20Data%20Validasi.csv"
df_all = pd.read_csv(path_1)
df_val = pd.read_csv(path_2)

# %% [markdown]
# ##**Dataframe for each experiment**

# %%
df1 = pd.read_csv(path_1) #untuk eksperimen 1
df1.head()
# Out:
#    Customer ID  Branch Code     City  Age  Avg. Annual Income/Month  \
# 0     15565701         1001  Jakarta   29                  33000000
# 1     15565878         1005  Jakarta   68                  17000000
# 2     15566091         1009  Jakarta   25                  12000000
# 3     15566292         1008  Jakarta   42                  19000000
# 4     15566312         1009  Jakarta   43                  29000000
#
#    Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  Balance Q2  \
# 0         0.0                 1             1                1         0.0
# 1         0.0                 2             1                1         0.0
# 2         0.0                 2             1                0         0.0
# 3         0.0                 2             1                1         0.0
# 4         0.0                 2             1                0         0.0
#
#    ...  ActiveMember Q2  Balance Q3  NumOfProducts Q3  HasCrCard Q3  \
# 0  ...                0        0.00                 1             1
# 1  ...                0        0.00                 2             1
# 2  ...                0        0.00                 2             1
# 3  ...                0        0.00                 2             1
# 4  ...                0   678905.68                 2             1
#
#    ActiveMember Q3  Balance Q4  NumOfProducts Q4  HasCrCard Q4  \
# 0                0  1187036.18                 1             1
# 1                0        0.00                 2             1
# 2                0  1351820.24                 2             1
# 3                0        0.00                 2             1
# 4                1   431190.68                 2             1
#
#    ActiveMember Q4  Unpaid Tagging
# 0                1               1
# 1                0               0
# 2                1               0
# 3                0               0
# 4                1               0
#
# [5 rows x 22 columns]

# %%
df2 = pd.read_csv(path_1) #untuk eksperimen 2
df2.head()
# Out:
#    Customer ID  Branch Code     City  Age  Avg. Annual Income/Month  \
# 0     15565701         1001  Jakarta   29                  33000000
# 1     15565878         1005  Jakarta   68                  17000000
# 2     15566091         1009  Jakarta   25                  12000000
# 3     15566292         1008  Jakarta   42                  19000000
# 4     15566312         1009  Jakarta   43                  29000000
#
#    Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  Balance Q2  \
# 0         0.0                 1             1                1         0.0
# 1         0.0                 2             1                1         0.0
# 2         0.0                 2             1                0         0.0
# 3         0.0                 2             1                1         0.0
# 4         0.0                 2             1                0         0.0
#
#    ...  ActiveMember Q2  Balance Q3  NumOfProducts Q3  HasCrCard Q3  \
# 0  ...                0        0.00                 1             1
# 1  ...                0        0.00                 2             1
# 2  ...                0        0.00                 2             1
# 3  ...                0        0.00                 2             1
# 4  ...                0   678905.68                 2             1
#
#    ActiveMember Q3  Balance Q4  NumOfProducts Q4  HasCrCard Q4  \
# 0                0  1187036.18                 1             1
# 1                0        0.00                 2             1
# 2                0  1351820.24                 2             1
# 3                0        0.00                 2             1
# 4                1   431190.68                 2             1
#
#    ActiveMember Q4  Unpaid Tagging
# 0                1               1
# 1                0               0
# 2                1               0
# 3                0               0
# 4                1               0
#
# [5 rows x 22 columns]

# %% [markdown]
# #**Data Understanding**

# %% [markdown]
# ##**Location based customer disribution**

# %% [markdown]
# 1.   Sebaran Keseluruhan
# 2.   Sebaran nasabah gagal bayar

# %%
data1 = pd.DataFrame(\
                      #Mengelompokkan berdasarkan kota
                       df_all.groupby(by=['City'])['Customer ID']\
                      #Diagegatkan dengan menghitung jumlahnya (count)
                       .count()\
                      #Mengurutkan data
                       .sort_values(ascending=False)\
                      #reset nama header
                       .reset_index(name='Distribution by City'))
data1
# Out:
#        City  Distribution by City
# 0  Surabaya                  3767
# 1   Bandung                  1898
# 2   Jakarta                  1896

# %% [markdown]
# **Sebaran nasabah gagal bayar**

# %%
data2 = pd.DataFrame(\
                      #Mengelompokkan berdasarkan kota
                       df_all[df_all['Unpaid Tagging']==1].groupby(by=['City'])['Customer ID']\
                      #Diagegatkan dengan menghitung jumlahnya (count)
                       .count()\
                      #Mengurutkan data
                       .sort_values(ascending=False)\
                      #reset nama header
                       .reset_index(name='Distribution by City'))
data2
# Out:
#        City  Distribution by City
# 0  Surabaya                  1033
# 1   Bandung                   496
# 2   Jakarta                   490

# %% [markdown]
# ##**Customer Distribution by Age**

# %% [markdown]
# **Data keseluruhan**

# %%
data3 = pd.DataFrame(\
                      #Mengelompokkan berdasarkan usia                      df_all.groupby(by=['Age'])['Customer ID']\
                       df_all.groupby(by=['Age'])['Customer ID']\
                      #Diagegatkan dengan menghitung jumlahnya (count)
                       .count()\
                      #reset nama header
                       .reset_index(name='Distribution by Age'))
data3.sort_values(\
                  by=['Age'], \
                  ascending=True, \
                  inplace=True)
data3.plot(x='Age',
          y=['Distribution by Age'],
          kind='bar',
          grid=True,
          xlabel='Age',
          ylabel='# People',
          figsize=(12,7),
          rot=0,
          title='Cust. Distribution by Age',
          table=False,
          secondary_y = False)
# Out:
# <Axes: title={'center': 'Cust. Distribution by Age'}, xlabel='Age', ylabel='# People'>

# %% [markdown]
# **Data gagal bayar**

# %%
data4 = pd.DataFrame(\
                      #Mengelompokkan berdasarkan usia
                       df_all[df_all['Unpaid Tagging']==1].groupby(by=['Age'])['Customer ID']\
                      #Diagegatkan dengan menghitung jumlahnya (count)
                       .count()\
                      #reset nama header
                       .reset_index(name='Distribution by Age'))
data4.sort_values(\
                  by=['Age'], \
                  ascending=True, \
                  inplace=True)
data4.plot(x='Age',
          y=['Distribution by Age'],
          kind='bar',
          grid=True,
          xlabel='Age',
          ylabel='# People',
          figsize=(12,7),
          rot=0,
          title='Unpaid Cust. Distribution by Age',
          table=False,
          secondary_y = False)
# Out:
# <Axes: title={'center': 'Unpaid Cust. Distribution by Age'}, xlabel='Age', ylabel='# People'>

# %% [markdown]
# ##**Average annual balance**

# %%
df_checkbalance = df_all
df_checkbalance['Total Balance'] = df_checkbalance['Balance Q1'] + df_checkbalance['Balance Q2'] + df_checkbalance['Balance Q3'] + df_checkbalance['Balance Q4']
df_checkbalance['Avg Balance'] = (df_checkbalance['Balance Q1'] + df_checkbalance['Balance Q2'] + df_checkbalance['Balance Q3'] + df_checkbalance['Balance Q4'])/4

data5 = pd.DataFrame(\
                      df_checkbalance.groupby(by=['Unpaid Tagging'])['Total Balance']\
                      .mean()\
                      .reset_index(name='Avg Annual Balance'))
data5
# Out:
#    Unpaid Tagging  Avg Annual Balance
# 0               0        1.985924e+08
# 1               1        2.527238e+08

# %% [markdown]
# from the data above, we r getting information that unpaid customer punya lebih banyak balance daripada paid customer

# %%
data6 = pd.DataFrame(\
                      df_checkbalance.groupby(by=['Unpaid Tagging'])['Avg Balance']\
                      .mean()\
                      .reset_index(name='Avg Quarterly Balance'))
data6
# Out:
#    Unpaid Tagging  Avg Quarterly Balance
# 0               0           4.964809e+07
# 1               1           6.318095e+07

# %% [markdown]
# ##**Average product owned**

# %%
df_checkbalance['Avg Product'] = (df_checkbalance['NumOfProducts Q1'] +
                                   df_checkbalance['NumOfProducts Q2'] +
                                   df_checkbalance['NumOfProducts Q3'] +
                                   df_checkbalance['NumOfProducts Q4'])/4
data7 = pd.DataFrame(\
                      df_checkbalance.groupby(by=['Unpaid Tagging'])['Avg Product']\
                      .mean()\
                      .reset_index(name='Avg Product Owned'))
data7
# Out:
#    Unpaid Tagging  Avg Product Owned
# 0               0           1.667223
# 1               1           1.609336

# %%
df_all = df_all.drop(columns=['Total Balance', 'Avg Balance', 'Avg Product'])

# %% [markdown]
# #**Data Preparation**

# %% [markdown]
# ##**Duplicated and missing data handling**

# %%
df_all.duplicated().sum()
# Out:
# 0

# %%
df_all.isnull().sum()
# Out:
# Customer ID                 0
# Branch Code                 0
# City                        0
# Age                         0
# Avg. Annual Income/Month    0
# Balance Q1                  0
# NumOfProducts Q1            0
# HasCrCard Q1                0
# ActiveMember Q1             0
# Balance Q2                  0
# NumOfProducts Q2            0
# HasCrCard Q2                0
# ActiveMember Q2             0
# Balance Q3                  0
# NumOfProducts Q3            0
# HasCrCard Q3                0
# ActiveMember Q3             0
# Balance Q4                  0
# NumOfProducts Q4            0
# HasCrCard Q4                0
# ActiveMember Q4             0
# Unpaid Tagging              0
# dtype: int64

# %% [markdown]
# ##**Relevant variable adding**

# %% [markdown]
# 1.   Eksperimen 1: rata-rata saldo nasabah dalam 1 tahun terakhir dan perubahan saldo di Q4 terhadap Q1.
#
# 2.   Eksperimen 2: rata-rata saldo nasabah dalam 6 bulan terakhir dan perubahan saldo di Q4 terhadap Q1.

# %% [markdown]
# ###**Mean balance**

# %% [markdown]
# ####**Eksperimen 1**

# %%
df1['Mean Balance'] = (df1['Balance Q1'] + df1['Balance Q2'] + df1['Balance Q3'] + df1['Balance Q4'])/4
df1['Delta Balance'] = df1['Balance Q4'] - df1['Balance Q1']
df1.head()
# Out:
#    Customer ID  Branch Code     City  Age  Avg. Annual Income/Month  \
# 0     15565701         1001  Jakarta   29                  33000000
# 1     15565878         1005  Jakarta   68                  17000000
# 2     15566091         1009  Jakarta   25                  12000000
# 3     15566292         1008  Jakarta   42                  19000000
# 4     15566312         1009  Jakarta   43                  29000000
#
#    Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  Balance Q2  \
# 0         0.0                 1             1                1         0.0
# 1         0.0                 2             1                1         0.0
# 2         0.0                 2             1                0         0.0
# 3         0.0                 2             1                1         0.0
# 4         0.0                 2             1                0         0.0
#
#    ...  NumOfProducts Q3  HasCrCard Q3  ActiveMember Q3  Balance Q4  \
# 0  ...                 1             1                0  1187036.18
# 1  ...                 2             1                0        0.00
# 2  ...                 2             1                0  1351820.24
# 3  ...                 2             1                0        0.00
# 4  ...                 2             1                1   431190.68
#
#    NumOfProducts Q4  HasCrCard Q4  ActiveMember Q4  Unpaid Tagging  \
# 0                 1             1                1               1
# 1                 2             1                0               0
# 2                 2             1                1               0
# 3                 2             1                0               0
# 4                 2             1                1               0
#
#    Mean Balance  Delta Balance
# 0    296759.045     1187036.18
# 1         0.000           0.00
# 2    337955.060     1351820.24
# 3         0.000           0.00
# 4    277524.090      431190.68
#
# [5 rows x 24 columns]

# %% [markdown]
# ####**Eksperimen 2**

# %%
df2['Mean Balance']= (df2['Balance Q3'] + df2['Balance Q4'])/2
df2['Delta Balance'] = df2['Balance Q4'] - df2['Balance Q2']
df2.head()
# Out:
#    Customer ID  Branch Code     City  Age  Avg. Annual Income/Month  \
# 0     15565701         1001  Jakarta   29                  33000000
# 1     15565878         1005  Jakarta   68                  17000000
# 2     15566091         1009  Jakarta   25                  12000000
# 3     15566292         1008  Jakarta   42                  19000000
# 4     15566312         1009  Jakarta   43                  29000000
#
#    Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  Balance Q2  \
# 0         0.0                 1             1                1         0.0
# 1         0.0                 2             1                1         0.0
# 2         0.0                 2             1                0         0.0
# 3         0.0                 2             1                1         0.0
# 4         0.0                 2             1                0         0.0
#
#    ...  NumOfProducts Q3  HasCrCard Q3  ActiveMember Q3  Balance Q4  \
# 0  ...                 1             1                0  1187036.18
# 1  ...                 2             1                0        0.00
# 2  ...                 2             1                0  1351820.24
# 3  ...                 2             1                0        0.00
# 4  ...                 2             1                1   431190.68
#
#    NumOfProducts Q4  HasCrCard Q4  ActiveMember Q4  Unpaid Tagging  \
# 0                 1             1                1               1
# 1                 2             1                0               0
# 2                 2             1                1               0
# 3                 2             1                0               0
# 4                 2             1                1               0
#
#    Mean Balance  Delta Balance
# 0     593518.09     1187036.18
# 1          0.00           0.00
# 2     675910.12     1351820.24
# 3          0.00           0.00
# 4     555048.18      431190.68
#
# [5 rows x 24 columns]

# %% [markdown]
# ###**Active status**

# %% [markdown]
# ####**Eksperimen 1**

# %%
df1['Active Months'] = (df1['ActiveMember Q1'] + df1['ActiveMember Q2'] + df1['ActiveMember Q3'] + df1['ActiveMember Q4'])*3
df1.head()
# Out:
#    Customer ID  Branch Code     City  Age  Avg. Annual Income/Month  \
# 0     15565701         1001  Jakarta   29                  33000000
# 1     15565878         1005  Jakarta   68                  17000000
# 2     15566091         1009  Jakarta   25                  12000000
# 3     15566292         1008  Jakarta   42                  19000000
# 4     15566312         1009  Jakarta   43                  29000000
#
#    Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  Balance Q2  \
# 0         0.0                 1             1                1         0.0
# 1         0.0                 2             1                1         0.0
# 2         0.0                 2             1                0         0.0
# 3         0.0                 2             1                1         0.0
# 4         0.0                 2             1                0         0.0
#
#    ...  HasCrCard Q3  ActiveMember Q3  Balance Q4  NumOfProducts Q4  \
# 0  ...             1                0  1187036.18                 1
# 1  ...             1                0        0.00                 2
# 2  ...             1                0  1351820.24                 2
# 3  ...             1                0        0.00                 2
# 4  ...             1                1   431190.68                 2
#
#    HasCrCard Q4  ActiveMember Q4  Unpaid Tagging  Mean Balance  Delta Balance  \
# 0             1                1               1    296759.045     1187036.18
# 1             1                0               0         0.000           0.00
# 2             1                1               0    337955.060     1351820.24
# 3             1                0               0         0.000           0.00
# 4             1                1               0    277524.090      431190.68
#
#    Active Months
# 0              6
# 1              3
# 2              3
# 3              3
# 4              6
#
# [5 rows x 25 columns]

# %% [markdown]
# ####**Eksperimen 2**

# %%
df2['Active Months'] = (df2['ActiveMember Q3'] + df2['ActiveMember Q4'])*3
df2.head()
# Out:
#    Customer ID  Branch Code     City  Age  Avg. Annual Income/Month  \
# 0     15565701         1001  Jakarta   29                  33000000
# 1     15565878         1005  Jakarta   68                  17000000
# 2     15566091         1009  Jakarta   25                  12000000
# 3     15566292         1008  Jakarta   42                  19000000
# 4     15566312         1009  Jakarta   43                  29000000
#
#    Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  Balance Q2  \
# 0         0.0                 1             1                1         0.0
# 1         0.0                 2             1                1         0.0
# 2         0.0                 2             1                0         0.0
# 3         0.0                 2             1                1         0.0
# 4         0.0                 2             1                0         0.0
#
#    ...  HasCrCard Q3  ActiveMember Q3  Balance Q4  NumOfProducts Q4  \
# 0  ...             1                0  1187036.18                 1
# 1  ...             1                0        0.00                 2
# 2  ...             1                0  1351820.24                 2
# 3  ...             1                0        0.00                 2
# 4  ...             1                1   431190.68                 2
#
#    HasCrCard Q4  ActiveMember Q4  Unpaid Tagging  Mean Balance  Delta Balance  \
# 0             1                1               1     593518.09     1187036.18
# 1             1                0               0          0.00           0.00
# 2             1                1               0     675910.12     1351820.24
# 3             1                0               0          0.00           0.00
# 4             1                1               0     555048.18      431190.68
#
#    Active Months
# 0              3
# 1              0
# 2              3
# 3              0
# 4              6
#
# [5 rows x 25 columns]

# %% [markdown]
# ###**Product Handling**

# %% [markdown]
# ####**Eksperimen 1**

# %%
df1['Diff PH'] = df1['NumOfProducts Q4'] - df1['NumOfProducts Q1']
df1.head()
# Out:
#    Customer ID  Branch Code     City  Age  Avg. Annual Income/Month  \
# 0     15565701         1001  Jakarta   29                  33000000
# 1     15565878         1005  Jakarta   68                  17000000
# 2     15566091         1009  Jakarta   25                  12000000
# 3     15566292         1008  Jakarta   42                  19000000
# 4     15566312         1009  Jakarta   43                  29000000
#
#    Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  Balance Q2  \
# 0         0.0                 1             1                1         0.0
# 1         0.0                 2             1                1         0.0
# 2         0.0                 2             1                0         0.0
# 3         0.0                 2             1                1         0.0
# 4         0.0                 2             1                0         0.0
#
#    ...  ActiveMember Q3  Balance Q4  NumOfProducts Q4  HasCrCard Q4  \
# 0  ...                0  1187036.18                 1             1
# 1  ...                0        0.00                 2             1
# 2  ...                0  1351820.24                 2             1
# 3  ...                0        0.00                 2             1
# 4  ...                1   431190.68                 2             1
#
#    ActiveMember Q4  Unpaid Tagging  Mean Balance  Delta Balance  \
# 0                1               1    296759.045     1187036.18
# 1                0               0         0.000           0.00
# 2                1               0    337955.060     1351820.24
# 3                0               0         0.000           0.00
# 4                1               0    277524.090      431190.68
#
#    Active Months  Diff PH
# 0              6        0
# 1              3        0
# 2              3        0
# 3              3        0
# 4              6        0
#
# [5 rows x 26 columns]

# %% [markdown]
# ####**Eksperimen 2**

# %%
df2['Diff PH'] = df2['NumOfProducts Q4'] - df2['NumOfProducts Q2']
df2.head()
# Out:
#    Customer ID  Branch Code     City  Age  Avg. Annual Income/Month  \
# 0     15565701         1001  Jakarta   29                  33000000
# 1     15565878         1005  Jakarta   68                  17000000
# 2     15566091         1009  Jakarta   25                  12000000
# 3     15566292         1008  Jakarta   42                  19000000
# 4     15566312         1009  Jakarta   43                  29000000
#
#    Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  Balance Q2  \
# 0         0.0                 1             1                1         0.0
# 1         0.0                 2             1                1         0.0
# 2         0.0                 2             1                0         0.0
# 3         0.0                 2             1                1         0.0
# 4         0.0                 2             1                0         0.0
#
#    ...  ActiveMember Q3  Balance Q4  NumOfProducts Q4  HasCrCard Q4  \
# 0  ...                0  1187036.18                 1             1
# 1  ...                0        0.00                 2             1
# 2  ...                0  1351820.24                 2             1
# 3  ...                0        0.00                 2             1
# 4  ...                1   431190.68                 2             1
#
#    ActiveMember Q4  Unpaid Tagging  Mean Balance  Delta Balance  \
# 0                1               1     593518.09     1187036.18
# 1                0               0          0.00           0.00
# 2                1               0     675910.12     1351820.24
# 3                0               0          0.00           0.00
# 4                1               0     555048.18      431190.68
#
#    Active Months  Diff PH
# 0              3        0
# 1              0        0
# 2              3        0
# 3              0        0
# 4              6        0
#
# [5 rows x 26 columns]

# %% [markdown]
# ###**Vintage Cr**
#
# lama kepemilikan kartu dalam periode observasi

# %%
def assign_cr1(df):
  if df['HasCrCard Q1'] == 1:
    return 12
  elif df['HasCrCard Q2'] == 1:
    return 9
  elif df['HasCrCard Q3'] == 1:
    return 6
  else:
    return 3
  return np.nan

# %% [markdown]
# ####**Eksperimen 1**

# %%
df1['Vintage_CR'] = df1.apply(assign_cr1, axis=1)
df1.head()
# Out:
#    Customer ID  Branch Code     City  Age  Avg. Annual Income/Month  \
# 0     15565701         1001  Jakarta   29                  33000000
# 1     15565878         1005  Jakarta   68                  17000000
# 2     15566091         1009  Jakarta   25                  12000000
# 3     15566292         1008  Jakarta   42                  19000000
# 4     15566312         1009  Jakarta   43                  29000000
#
#    Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  Balance Q2  \
# 0         0.0                 1             1                1         0.0
# 1         0.0                 2             1                1         0.0
# 2         0.0                 2             1                0         0.0
# 3         0.0                 2             1                1         0.0
# 4         0.0                 2             1                0         0.0
#
#    ...  Balance Q4  NumOfProducts Q4  HasCrCard Q4  ActiveMember Q4  \
# 0  ...  1187036.18                 1             1                1
# 1  ...        0.00                 2             1                0
# 2  ...  1351820.24                 2             1                1
# 3  ...        0.00                 2             1                0
# 4  ...   431190.68                 2             1                1
#
#    Unpaid Tagging  Mean Balance  Delta Balance  Active Months  Diff PH  \
# 0               1    296759.045     1187036.18              6        0
# 1               0         0.000           0.00              3        0
# 2               0    337955.060     1351820.24              3        0
# 3               0         0.000           0.00              3        0
# 4               0    277524.090      431190.68              6        0
#
#    Vintage_CR
# 0          12
# 1          12
# 2          12
# 3          12
# 4          12
#
# [5 rows x 27 columns]

# %% [markdown]
# ####**Eksperimen 2**

# %%
df2['Vintage_CR'] = df2.apply(assign_cr1, axis=1)
df2.head()
# Out:
#    Customer ID  Branch Code     City  Age  Avg. Annual Income/Month  \
# 0     15565701         1001  Jakarta   29                  33000000
# 1     15565878         1005  Jakarta   68                  17000000
# 2     15566091         1009  Jakarta   25                  12000000
# 3     15566292         1008  Jakarta   42                  19000000
# 4     15566312         1009  Jakarta   43                  29000000
#
#    Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  Balance Q2  \
# 0         0.0                 1             1                1         0.0
# 1         0.0                 2             1                1         0.0
# 2         0.0                 2             1                0         0.0
# 3         0.0                 2             1                1         0.0
# 4         0.0                 2             1                0         0.0
#
#    ...  Balance Q4  NumOfProducts Q4  HasCrCard Q4  ActiveMember Q4  \
# 0  ...  1187036.18                 1             1                1
# 1  ...        0.00                 2             1                0
# 2  ...  1351820.24                 2             1                1
# 3  ...        0.00                 2             1                0
# 4  ...   431190.68                 2             1                1
#
#    Unpaid Tagging  Mean Balance  Delta Balance  Active Months  Diff PH  \
# 0               1     593518.09     1187036.18              3        0
# 1               0          0.00           0.00              0        0
# 2               0     675910.12     1351820.24              3        0
# 3               0          0.00           0.00              0        0
# 4               0     555048.18      431190.68              6        0
#
#    Vintage_CR
# 0          12
# 1          12
# 2          12
# 3          12
# 4          12
#
# [5 rows x 27 columns]

# %% [markdown]
# ##**Variable removing**

# %% [markdown]
# Status kepemilikan sudah digantikan dengan lama kepemilikan kartu kredit.
#
# HasCrCard ->> vintage_cr

# %%
df1 = df1.drop(columns = ['HasCrCard Q1', 'HasCrCard Q2', 'HasCrCard Q3', 'HasCrCard Q4'])
df2 = df2.drop(columns = ['HasCrCard Q1', 'HasCrCard Q2', 'HasCrCard Q3', 'HasCrCard Q4'])

# %% [markdown]
# Balance Per Quarter sudah digantikan dengan rata-rata saldo dalam periode observasi dan selisih saldo di awal dan akhir periode observasi.
#
# balance ->> mean_balance

# %%
df1 = df1.drop(columns = ['Balance Q1','Balance Q2','Balance Q3','Balance Q4'])
df2 = df2.drop(columns = ['Balance Q1','Balance Q2','Balance Q3','Balance Q4'])

# %% [markdown]
# NumOfProducts ->> diff_PH

# %%
df1 = df1.drop(columns = ['NumOfProducts Q1','NumOfProducts Q2', 'NumOfProducts Q3', 'NumOfProducts Q4'])
df2 = df2.drop(columns = ['NumOfProducts Q1','NumOfProducts Q2', 'NumOfProducts Q3', 'NumOfProducts Q4'])

# %% [markdown]
# activeMember ->> active month

# %%
df1 = df1.drop(columns = ['ActiveMember Q1','ActiveMember Q2', 'ActiveMember Q3', 'ActiveMember Q4'])
df2 = df2.drop(columns = ['ActiveMember Q1','ActiveMember Q2', 'ActiveMember Q3', 'ActiveMember Q4'])

# %% [markdown]
# ##**Data Transformation**

# %% [markdown]
# ###**Predictor Variable Separating**

# %%
predictor1 = df1[df1.columns.difference(['Customer ID', 'Unpaid Tagging'])]
predictor2 = df2[df2.columns.difference(['Customer ID', 'Unpaid Tagging'])]

# %%
predictor1.head()
# Out:
#    Active Months  Age  Avg. Annual Income/Month  Branch Code     City  \
# 0              6   29                  33000000         1001  Jakarta
# 1              3   68                  17000000         1005  Jakarta
# 2              3   25                  12000000         1009  Jakarta
# 3              3   42                  19000000         1008  Jakarta
# 4              6   43                  29000000         1009  Jakarta
#
#    Delta Balance  Diff PH  Mean Balance  Vintage_CR
# 0     1187036.18        0    296759.045          12
# 1           0.00        0         0.000          12
# 2     1351820.24        0    337955.060          12
# 3           0.00        0         0.000          12
# 4      431190.68        0    277524.090          12

# %%
predictor2.head()
# Out:
#    Active Months  Age  Avg. Annual Income/Month  Branch Code     City  \
# 0              3   29                  33000000         1001  Jakarta
# 1              0   68                  17000000         1005  Jakarta
# 2              3   25                  12000000         1009  Jakarta
# 3              0   42                  19000000         1008  Jakarta
# 4              6   43                  29000000         1009  Jakarta
#
#    Delta Balance  Diff PH  Mean Balance  Vintage_CR
# 0     1187036.18        0     593518.09          12
# 1           0.00        0          0.00          12
# 2     1351820.24        0     675910.12          12
# 3           0.00        0          0.00          12
# 4      431190.68        0     555048.18          12

# %% [markdown]
# ###**Data Category Encoding**

# %% [markdown]
# Kategori variabel:
#
# 1. Branch Code
#
# 2. City
#
# Untuk branch code perlu diubah menjadi string agar dianggap sebagai data kategori.

# %%
predictor1['Branch Code'] = predictor1['Branch Code'].astype(str)
predictor2['Branch Code'] = predictor2['Branch Code'].astype(str)
# Out:
# <ipython-input-310-b9748522fe9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictor1['Branch Code'] = predictor1['Branch Code'].astype(str)
# <ipython-input-310-b9748522fe9d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictor2['Branch Code'] = predictor2['Branch Code'].astype(str)

# %%
predictor1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7561 entries, 0 to 7560
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Active Months             7561 non-null   int64
#  1   Age                       7561 non-null   int64
#  2   Avg. Annual Income/Month  7561 non-null   int64
#  3   Branch Code               7561 non-null   object
#  4   City                      7561 non-null   object
#  5   Delta Balance             7561 non-null   float64
#  6   Diff PH                   7561 non-null   int64
#  7   Mean Balance              7561 non-null   float64
#  8   Vintage_CR                7561 non-null   int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 531.8+ KB

# %%
predictor2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7561 entries, 0 to 7560
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Active Months             7561 non-null   int64
#  1   Age                       7561 non-null   int64
#  2   Avg. Annual Income/Month  7561 non-null   int64
#  3   Branch Code               7561 non-null   object
#  4   City                      7561 non-null   object
#  5   Delta Balance             7561 non-null   float64
#  6   Diff PH                   7561 non-null   int64
#  7   Mean Balance              7561 non-null   float64
#  8   Vintage_CR                7561 non-null   int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 531.8+ KB

# %% [markdown]
#  ubah tipe data kategori menjadi variable indikator/dummy.

# %%
predictor1 = pd.get_dummies(predictor1)
predictor2 = pd.get_dummies(predictor2)

# %%
predictor1.head()
# Out:
#    Active Months  Age  Avg. Annual Income/Month  Delta Balance  Diff PH  \
# 0              6   29                  33000000     1187036.18        0
# 1              3   68                  17000000           0.00        0
# 2              3   25                  12000000     1351820.24        0
# 3              3   42                  19000000           0.00        0
# 4              6   43                  29000000      431190.68        0
#
#    Mean Balance  Vintage_CR  Branch Code_1001  Branch Code_1002  \
# 0    296759.045          12              True             False
# 1         0.000          12             False             False
# 2    337955.060          12             False             False
# 3         0.000          12             False             False
# 4    277524.090          12             False             False
#
#    Branch Code_1003  ...  Branch Code_1013  Branch Code_1014  \
# 0             False  ...             False             False
# 1             False  ...             False             False
# 2             False  ...             False             False
# 3             False  ...             False             False
# 4             False  ...             False             False
#
#    Branch Code_1015  Branch Code_1021  Branch Code_1022  Branch Code_1023  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
#    Branch Code_1024  City_Bandung  City_Jakarta  City_Surabaya
# 0             False         False          True          False
# 1             False         False          True          False
# 2             False         False          True          False
# 3             False         False          True          False
# 4             False         False          True          False
#
# [5 rows x 28 columns]

# %%
predictor2.head()
# Out:
#    Active Months  Age  Avg. Annual Income/Month  Delta Balance  Diff PH  \
# 0              3   29                  33000000     1187036.18        0
# 1              0   68                  17000000           0.00        0
# 2              3   25                  12000000     1351820.24        0
# 3              0   42                  19000000           0.00        0
# 4              6   43                  29000000      431190.68        0
#
#    Mean Balance  Vintage_CR  Branch Code_1001  Branch Code_1002  \
# 0     593518.09          12              True             False
# 1          0.00          12             False             False
# 2     675910.12          12             False             False
# 3          0.00          12             False             False
# 4     555048.18          12             False             False
#
#    Branch Code_1003  ...  Branch Code_1013  Branch Code_1014  \
# 0             False  ...             False             False
# 1             False  ...             False             False
# 2             False  ...             False             False
# 3             False  ...             False             False
# 4             False  ...             False             False
#
#    Branch Code_1015  Branch Code_1021  Branch Code_1022  Branch Code_1023  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
#    Branch Code_1024  City_Bandung  City_Jakarta  City_Surabaya
# 0             False         False          True          False
# 1             False         False          True          False
# 2             False         False          True          False
# 3             False         False          True          False
# 4             False         False          True          False
#
# [5 rows x 28 columns]

# %%
predname = predictor1.columns
predname_num = predictor1.columns[0:7] #mengambil kolom yang numerik
predname_cat = predictor1.columns[7:31] #mengambil kolom yang sifatnya kategorik

# %%
X1_num = predictor1[predname_num]
X2_num = predictor2[predname_num]
X1_cat = predictor1[predname_cat]
X2_cat = predictor2[predname_cat]

# %% [markdown]
# ##**Numeric Data Standardization**

# %% [markdown]
# ###**Eksperimen 1**

# %%
from sklearn.preprocessing import StandardScaler
pt = StandardScaler()
X1_num = pd.DataFrame(pt.fit_transform(X1_num))

X1_num.head()
# Out:
#           0         1         2         3         4         5         6
# 0 -0.135176 -1.185374  0.663649  1.964593 -0.531491 -0.947970  0.296502
# 1 -1.013239  1.580668 -0.680854 -0.319523 -0.531491 -0.953281  0.296502
# 2 -1.013239 -1.469071 -1.101011  2.281673 -0.531491 -0.947232  0.296502
# 3 -1.013239 -0.263360 -0.512791 -0.319523 -0.531491 -0.953281  0.296502
# 4 -0.135176 -0.192436  0.327524  0.510182 -0.531491 -0.948314  0.296502

# %%
#ganti nama kolom

X1_num.columns = predname_num
X1_num.head()
# Out:
#    Active Months       Age  Avg. Annual Income/Month  Delta Balance   Diff PH  \
# 0      -0.135176 -1.185374                  0.663649       1.964593 -0.531491
# 1      -1.013239  1.580668                 -0.680854      -0.319523 -0.531491
# 2      -1.013239 -1.469071                 -1.101011       2.281673 -0.531491
# 3      -1.013239 -0.263360                 -0.512791      -0.319523 -0.531491
# 4      -0.135176 -0.192436                  0.327524       0.510182 -0.531491
#
#    Mean Balance  Vintage_CR
# 0     -0.947970    0.296502
# 1     -0.953281    0.296502
# 2     -0.947232    0.296502
# 3     -0.953281    0.296502
# 4     -0.948314    0.296502

# %% [markdown]
# ###**Eksperimen 2**

# %%
X2_num = pd.DataFrame(pt.fit_transform(X2_num))
X2_num.head()
# Out:
#           0         1         2         3         4         5         6
# 0 -0.165835 -1.185374  0.663649  2.641819 -0.440014 -0.944440  0.296502
# 1 -1.471959  1.580668 -0.680854 -0.233476 -0.440014 -0.955071  0.296502
# 2 -0.165835 -1.469071 -1.101011  3.040967 -0.440014 -0.942964  0.296502
# 3 -1.471959 -0.263360 -0.512791 -0.233476 -0.440014 -0.955071  0.296502
# 4  1.140289 -0.192436  0.327524  0.810974 -0.440014 -0.945129  0.296502

# %%
#ganti nama kolom

X2_num.columns = predname_num
X2_num.head()
# Out:
#    Active Months       Age  Avg. Annual Income/Month  Delta Balance   Diff PH  \
# 0      -0.165835 -1.185374                  0.663649       2.641819 -0.440014
# 1      -1.471959  1.580668                 -0.680854      -0.233476 -0.440014
# 2      -0.165835 -1.469071                 -1.101011       3.040967 -0.440014
# 3      -1.471959 -0.263360                 -0.512791      -0.233476 -0.440014
# 4       1.140289 -0.192436                  0.327524       0.810974 -0.440014
#
#    Mean Balance  Vintage_CR
# 0     -0.944440    0.296502
# 1     -0.955071    0.296502
# 2     -0.942964    0.296502
# 3     -0.955071    0.296502
# 4     -0.945129    0.296502

# %% [markdown]
# ##**Grouping predictor dataset**

# %% [markdown]
# gabungin data predictor

# %%
X1 = pd.concat([X1_cat, X1_num], axis = 1)
X2 = pd.concat([X2_cat, X2_num], axis = 1)
X1.head()
# Out:
#    Branch Code_1001  Branch Code_1002  Branch Code_1003  Branch Code_1004  \
# 0              True             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
#    Branch Code_1005  Branch Code_1006  Branch Code_1007  Branch Code_1008  \
# 0             False             False             False             False
# 1              True             False             False             False
# 2             False             False             False             False
# 3             False             False             False              True
# 4             False             False             False             False
#
#    Branch Code_1009  Branch Code_1011  ...  City_Bandung  City_Jakarta  \
# 0             False             False  ...         False          True
# 1             False             False  ...         False          True
# 2              True             False  ...         False          True
# 3             False             False  ...         False          True
# 4              True             False  ...         False          True
#
#    City_Surabaya  Active Months       Age  Avg. Annual Income/Month  \
# 0          False      -0.135176 -1.185374                  0.663649
# 1          False      -1.013239  1.580668                 -0.680854
# 2          False      -1.013239 -1.469071                 -1.101011
# 3          False      -1.013239 -0.263360                 -0.512791
# 4          False      -0.135176 -0.192436                  0.327524
#
#    Delta Balance   Diff PH  Mean Balance  Vintage_CR
# 0       1.964593 -0.531491     -0.947970    0.296502
# 1      -0.319523 -0.531491     -0.953281    0.296502
# 2       2.281673 -0.531491     -0.947232    0.296502
# 3      -0.319523 -0.531491     -0.953281    0.296502
# 4       0.510182 -0.531491     -0.948314    0.296502
#
# [5 rows x 28 columns]

# %%
X2.head()
# Out:
#    Branch Code_1001  Branch Code_1002  Branch Code_1003  Branch Code_1004  \
# 0              True             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
#    Branch Code_1005  Branch Code_1006  Branch Code_1007  Branch Code_1008  \
# 0             False             False             False             False
# 1              True             False             False             False
# 2             False             False             False             False
# 3             False             False             False              True
# 4             False             False             False             False
#
#    Branch Code_1009  Branch Code_1011  ...  City_Bandung  City_Jakarta  \
# 0             False             False  ...         False          True
# 1             False             False  ...         False          True
# 2              True             False  ...         False          True
# 3             False             False  ...         False          True
# 4              True             False  ...         False          True
#
#    City_Surabaya  Active Months       Age  Avg. Annual Income/Month  \
# 0          False      -0.165835 -1.185374                  0.663649
# 1          False      -1.471959  1.580668                 -0.680854
# 2          False      -0.165835 -1.469071                 -1.101011
# 3          False      -1.471959 -0.263360                 -0.512791
# 4          False       1.140289 -0.192436                  0.327524
#
#    Delta Balance   Diff PH  Mean Balance  Vintage_CR
# 0       2.641819 -0.440014     -0.944440    0.296502
# 1      -0.233476 -0.440014     -0.955071    0.296502
# 2       3.040967 -0.440014     -0.942964    0.296502
# 3      -0.233476 -0.440014     -0.955071    0.296502
# 4       0.810974 -0.440014     -0.945129    0.296502
#
# [5 rows x 28 columns]

# %%
#variabel dependen
y1 = df1['Unpaid Tagging']
y2 = df2['Unpaid Tagging']

# %% [markdown]
# ##**Preparing Dataset for Validation**

# %% [markdown]
# ###**Import Data**

# %%
df1_val = pd.read_csv(path_2) #untuk eksperimen 1
df2_val = pd.read_csv(path_2) #untuk eksperimen 2

# %% [markdown]
# *   Penambahan variabel relevan

# %%
df1_val['Mean Balance'] = (df1_val['Balance Q2'] + df1_val['Balance Q3'] + df1_val['Balance Q4'] + df1_val['Balance Q5'])/4
df1_val['Delta Balance'] = df1_val['Balance Q4'] - df1_val['Balance Q5']

df2_val['Mean Balance']= (df2_val['Balance Q5'] + df2_val['Balance Q2'])/2
df2_val['Delta Balance'] = df2_val['Balance Q5'] - df2_val['Balance Q3']

# %% [markdown]
# *   Status keaktifan

# %%
df1_val['Active Months'] = (df1_val['Balance Q3'] + df1_val['Balance Q2'] + df1_val['Balance Q5'] + df1_val['Balance Q4'])*3
df2_val['Active Months']= (df2_val['Balance Q4'] + df2_val['Balance Q5'])*3

# %% [markdown]
# *  Product Handling

# %%
df1_val['Diff PH'] = df1_val['Balance Q5'] - df1_val['Balance Q2']
df2_val['Diff PH'] = df2_val['Balance Q5'] - df2_val['Balance Q3']

# %% [markdown]
# *  Vintage CR

# %%
def assign_cr2(df):
  if df['HasCrCard Q2'] == 1:
    return 12
  elif df['HasCrCard Q3'] == 1:
    return 9
  elif df['HasCrCard Q4'] == 1:
    return 6
  else:
    return 3
  return np.nan

# %%
df1_val['Vintage_CR'] = df1_val.apply(assign_cr2, axis=1)
df2_val['Vintage_CR'] = df2_val.apply(assign_cr2, axis=1)

# %% [markdown]
# *  Variable removing

# %%
df1_val = df1_val.drop(columns = ['HasCrCard Q5', 'HasCrCard Q2', 'HasCrCard Q3', 'HasCrCard Q4', 'Balance Q5','Balance Q2','Balance Q3','Balance Q4', 'NumOfProducts Q5','NumOfProducts Q2', 'NumOfProducts Q3', 'NumOfProducts Q4', 'ActiveMember Q5','ActiveMember Q2', 'ActiveMember Q3', 'ActiveMember Q4'])
df2_val = df2_val.drop(columns = ['HasCrCard Q5', 'HasCrCard Q2', 'HasCrCard Q3', 'HasCrCard Q4', 'Balance Q5','Balance Q2','Balance Q3','Balance Q4', 'NumOfProducts Q5','NumOfProducts Q2', 'NumOfProducts Q3', 'NumOfProducts Q4', 'ActiveMember Q5','ActiveMember Q2', 'ActiveMember Q3', 'ActiveMember Q4'])

# %% [markdown]
# *  Predictor variable

# %%
predictor1_val = df1_val[df1_val.columns.difference(['Customer ID', 'Unpaid Tagging'])]
predictor2_val = df2_val[df2_val.columns.difference(['Customer ID', 'Unpaid Tagging'])]

predictor1_val['Branch Code'] = predictor1_val['Branch Code'].astype(str)
predictor2_val['Branch Code'] = predictor2_val['Branch Code'].astype(str)

predictor1_val = pd.get_dummies(predictor1_val)
predictor2_val = pd.get_dummies(predictor2_val)
# Out:
# <ipython-input-332-5603a55ecf71>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictor1_val['Branch Code'] = predictor1_val['Branch Code'].astype(str)
# <ipython-input-332-5603a55ecf71>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictor2_val['Branch Code'] = predictor2_val['Branch Code'].astype(str)

# %%
predname = predictor1_val.columns
predname_num = predictor1_val.columns[0:7] #mengambil kolom yang numerik
predname_cat = predictor1_val.columns[7:31] #mengambil kolom yang sifatnya kategorik

# %%
X1_num_val = predictor1_val[predname_num]
X2_num_val = predictor2_val[predname_num]

X1_cat_val = predictor1_val[predname_cat]
X2_cat_val = predictor2_val[predname_cat]

# %%
X1_num_val = pd.DataFrame(pt.fit_transform(X1_num_val))
X2_num_val = pd.DataFrame(pt.fit_transform(X2_num_val))

X1_val = pd.concat([X1_cat, X1_num], axis=1)
X2_val = pd.concat([X2_cat, X2_num], axis=1)

# %%
#variabel dependen
y1_val = df1_val['Unpaid Tagging']
y2_val = df2_val['Unpaid Tagging']

# %% [markdown]
# ##**Correlation Cheking**

# %%
corrtest1 = X1.corr().abs() #tanpa melihat arah korelasinya apakah bernilai positif atau negatif, hanya melihat nilai korelasi absolutnya
corrtest2 = X2.corr().abs()

# %%
corrtest1
# Out:
#                           Branch Code_1001  Branch Code_1002  \
# Branch Code_1001                  1.000000          0.028917
# Branch Code_1002                  0.028917          1.000000
# Branch Code_1003                  0.028917          0.029128
# Branch Code_1004                  0.029673          0.029889
# Branch Code_1005                  0.029331          0.029545
# Branch Code_1006                  0.027640          0.027842
# Branch Code_1007                  0.028000          0.028204
# Branch Code_1008                  0.028214          0.028420
# Branch Code_1009                  0.028707          0.028917
# Branch Code_1011                  0.040203          0.040496
# Branch Code_1012                  0.039566          0.039855
# Branch Code_1013                  0.039353          0.039639
# Branch Code_1014                  0.038159          0.038437
# Branch Code_1015                  0.037440          0.037713
# Branch Code_1021                  0.064383          0.064852
# Branch Code_1022                  0.062555          0.063011
# Branch Code_1023                  0.063414          0.063876
# Branch Code_1024                  0.065268          0.065744
# City_Bandung                      0.098089          0.098804
# City_Jakarta                      0.292872          0.295007
# City_Surabaya                     0.168829          0.170060
# Active Months                     0.000365          0.007664
# Age                               0.010394          0.006371
# Avg. Annual Income/Month          0.003603          0.016078
# Delta Balance                     0.001462          0.004592
# Diff PH                           0.003888          0.003957
# Mean Balance                      0.009732          0.005634
# Vintage_CR                        0.020774          0.034256
#
#                           Branch Code_1003  Branch Code_1004  \
# Branch Code_1001                  0.028917          0.029673
# Branch Code_1002                  0.029128          0.029889
# Branch Code_1003                  1.000000          0.029889
# Branch Code_1004                  0.029889          1.000000
# Branch Code_1005                  0.029545          0.030318
# Branch Code_1006                  0.027842          0.028570
# Branch Code_1007                  0.028204          0.028941
# Branch Code_1008                  0.028420          0.029163
# Branch Code_1009                  0.028917          0.029673
# Branch Code_1011                  0.040496          0.041555
# Branch Code_1012                  0.039855          0.040897
# Branch Code_1013                  0.039639          0.040676
# Branch Code_1014                  0.038437          0.039442
# Branch Code_1015                  0.037713          0.038699
# Branch Code_1021                  0.064852          0.066548
# Branch Code_1022                  0.063011          0.064658
# Branch Code_1023                  0.063876          0.065546
# Branch Code_1024                  0.065744          0.067463
# City_Bandung                      0.098804          0.101388
# City_Jakarta                      0.295007          0.302721
# City_Surabaya                     0.170060          0.174506
# Active Months                     0.018168          0.001120
# Age                               0.013724          0.008420
# Avg. Annual Income/Month          0.001937          0.002095
# Delta Balance                     0.008577          0.015427
# Diff PH                           0.004227          0.001172
# Mean Balance                      0.001776          0.013269
# Vintage_CR                        0.021341          0.003376
#
#                           Branch Code_1005  Branch Code_1006  \
# Branch Code_1001                  0.029331          0.027640
# Branch Code_1002                  0.029545          0.027842
# Branch Code_1003                  0.029545          0.027842
# Branch Code_1004                  0.030318          0.028570
# Branch Code_1005                  1.000000          0.028241
# Branch Code_1006                  0.028241          1.000000
# Branch Code_1007                  0.028608          0.026959
# Branch Code_1008                  0.028827          0.027165
# Branch Code_1009                  0.029331          0.027640
# Branch Code_1011                  0.041076          0.038708
# Branch Code_1012                  0.040426          0.038095
# Branch Code_1013                  0.040208          0.037889
# Branch Code_1014                  0.038988          0.036740
# Branch Code_1015                  0.038253          0.036048
# Branch Code_1021                  0.065782          0.061989
# Branch Code_1022                  0.063914          0.060229
# Branch Code_1023                  0.064792          0.061056
# Branch Code_1024                  0.066686          0.062841
# City_Bandung                      0.100221          0.094442
# City_Jakarta                      0.299236          0.281983
# City_Surabaya                     0.172498          0.162551
# Active Months                     0.011655          0.006704
# Age                               0.001335          0.004534
# Avg. Annual Income/Month          0.008829          0.007488
# Delta Balance                     0.010599          0.000112
# Diff PH                           0.001569          0.017499
# Mean Balance                      0.007520          0.004003
# Vintage_CR                        0.002246          0.008669
#
#                           Branch Code_1007  Branch Code_1008  \
# Branch Code_1001                  0.028000          0.028214
# Branch Code_1002                  0.028204          0.028420
# Branch Code_1003                  0.028204          0.028420
# Branch Code_1004                  0.028941          0.029163
# Branch Code_1005                  0.028608          0.028827
# Branch Code_1006                  0.026959          0.027165
# Branch Code_1007                  1.000000          0.027518
# Branch Code_1008                  0.027518          1.000000
# Branch Code_1009                  0.028000          0.028214
# Branch Code_1011                  0.039212          0.039511
# Branch Code_1012                  0.038591          0.038886
# Branch Code_1013                  0.038383          0.038676
# Branch Code_1014                  0.037219          0.037503
# Branch Code_1015                  0.036517          0.036796
# Branch Code_1021                  0.062796          0.063276
# Branch Code_1022                  0.061013          0.061479
# Branch Code_1023                  0.061851          0.062323
# Branch Code_1024                  0.063659          0.064146
# City_Bandung                      0.095672          0.096403
# City_Jakarta                      0.285654          0.287836
# City_Surabaya                     0.164668          0.165926
# Active Months                     0.010148          0.000426
# Age                               0.011408          0.005992
# Avg. Annual Income/Month          0.024003          0.000678
# Delta Balance                     0.002511          0.003350
# Diff PH                           0.018648          0.006413
# Mean Balance                      0.006408          0.001808
# Vintage_CR                        0.003749          0.016428
#
#                           Branch Code_1009  Branch Code_1011  ...  \
# Branch Code_1001                  0.028707          0.040203  ...
# Branch Code_1002                  0.028917          0.040496  ...
# Branch Code_1003                  0.028917          0.040496  ...
# Branch Code_1004                  0.029673          0.041555  ...
# Branch Code_1005                  0.029331          0.041076  ...
# Branch Code_1006                  0.027640          0.038708  ...
# Branch Code_1007                  0.028000          0.039212  ...
# Branch Code_1008                  0.028214          0.039511  ...
# Branch Code_1009                  1.000000          0.040203  ...
# Branch Code_1011                  0.040203          1.000000  ...
# Branch Code_1012                  0.039566          0.055410  ...
# Branch Code_1013                  0.039353          0.055110  ...
# Branch Code_1014                  0.038159          0.053439  ...
# Branch Code_1015                  0.037440          0.052431  ...
# Branch Code_1021                  0.064383          0.090163  ...
# Branch Code_1022                  0.062555          0.087603  ...
# Branch Code_1023                  0.063414          0.088806  ...
# Branch Code_1024                  0.065268          0.091403  ...
# City_Bandung                      0.098089          0.409857  ...
# City_Jakarta                      0.292872          0.137270  ...
# City_Surabaya                     0.168829          0.236432  ...
# Active Months                     0.002480          0.001055  ...
# Age                               0.002933          0.011252  ...
# Avg. Annual Income/Month          0.012510          0.016018  ...
# Delta Balance                     0.001391          0.025531  ...
# Diff PH                           0.012129          0.004062  ...
# Mean Balance                      0.005874          0.005530  ...
# Vintage_CR                        0.014582          0.020666  ...
#
#                           City_Bandung  City_Jakarta  City_Surabaya  \
# Branch Code_1001              0.098089      0.292872       0.168829
# Branch Code_1002              0.098804      0.295007       0.170060
# Branch Code_1003              0.098804      0.295007       0.170060
# Branch Code_1004              0.101388      0.302721       0.174506
# Branch Code_1005              0.100221      0.299236       0.172498
# Branch Code_1006              0.094442      0.281983       0.162551
# Branch Code_1007              0.095672      0.285654       0.164668
# Branch Code_1008              0.096403      0.287836       0.165926
# Branch Code_1009              0.098089      0.292872       0.168829
# Branch Code_1011              0.409857      0.137270       0.236432
# Branch Code_1012              0.403370      0.135098       0.232690
# Branch Code_1013              0.401190      0.134367       0.231432
# Branch Code_1014              0.389024      0.130293       0.224414
# Branch Code_1015              0.381688      0.127836       0.220183
# Branch Code_1021              0.219987      0.219832       0.381349
# Branch Code_1022              0.213741      0.213590       0.370521
# Branch Code_1023              0.216676      0.216523       0.375609
# Branch Code_1024              0.223011      0.222855       0.386592
# City_Bandung                  1.000000      0.334922       0.576865
# City_Jakarta                  0.334922      1.000000       0.576459
# City_Surabaya                 0.576865      0.576459       1.000000
# Active Months                 0.009590      0.012294       0.002341
# Age                           0.018999      0.002929       0.013937
# Avg. Annual Income/Month      0.007774      0.000895       0.005966
# Delta Balance                 0.005927      0.003823       0.008455
# Diff PH                       0.001561      0.003138       0.004074
# Mean Balance                  0.001951      0.009902       0.006892
# Vintage_CR                    0.014970      0.010316       0.021926
#
#                           Active Months       Age  Avg. Annual Income/Month  \
# Branch Code_1001               0.000365  0.010394                  0.003603
# Branch Code_1002               0.007664  0.006371                  0.016078
# Branch Code_1003               0.018168  0.013724                  0.001937
# Branch Code_1004               0.001120  0.008420                  0.002095
# Branch Code_1005               0.011655  0.001335                  0.008829
# Branch Code_1006               0.006704  0.004534                  0.007488
# Branch Code_1007               0.010148  0.011408                  0.024003
# Branch Code_1008               0.000426  0.005992                  0.000678
# Branch Code_1009               0.002480  0.002933                  0.012510
# Branch Code_1011               0.001055  0.011252                  0.016018
# Branch Code_1012               0.012163  0.012025                  0.002862
# Branch Code_1013               0.010762  0.027836                  0.002401
# Branch Code_1014               0.021568  0.028956                  0.030870
# Branch Code_1015               0.000447  0.005162                  0.003849
# Branch Code_1021               0.017534  0.023573                  0.013912
# Branch Code_1022               0.012378  0.017031                  0.005639
# Branch Code_1023               0.006008  0.010069                  0.002502
# Branch Code_1024               0.007757  0.009204                  0.025677
# City_Bandung                   0.009590  0.018999                  0.007774
# City_Jakarta                   0.012294  0.002929                  0.000895
# City_Surabaya                  0.002341  0.013937                  0.005966
# Active Months                  1.000000  0.023447                  0.012587
# Age                            0.023447  1.000000                  0.158954
# Avg. Annual Income/Month       0.012587  0.158954                  1.000000
# Delta Balance                  0.054249  0.008340                  0.010524
# Diff PH                        0.007048  0.000567                  0.004438
# Mean Balance                   0.293083  0.016806                  0.014371
# Vintage_CR                     0.012810  0.002657                  0.009442
#
#                           Delta Balance   Diff PH  Mean Balance  Vintage_CR
# Branch Code_1001               0.001462  0.003888      0.009732    0.020774
# Branch Code_1002               0.004592  0.003957      0.005634    0.034256
# Branch Code_1003               0.008577  0.004227      0.001776    0.021341
# Branch Code_1004               0.015427  0.001172      0.013269    0.003376
# Branch Code_1005               0.010599  0.001569      0.007520    0.002246
# Branch Code_1006               0.000112  0.017499      0.004003    0.008669
# Branch Code_1007               0.002511  0.018648      0.006408    0.003749
# Branch Code_1008               0.003350  0.006413      0.001808    0.016428
# Branch Code_1009               0.001391  0.012129      0.005874    0.014582
# Branch Code_1011               0.025531  0.004062      0.005530    0.020666
# Branch Code_1012               0.010182  0.027278      0.009312    0.007458
# Branch Code_1013               0.000408  0.020672      0.006893    0.005006
# Branch Code_1014               0.018740  0.015804      0.006013    0.021498
# Branch Code_1015               0.010078  0.001487      0.013203    0.010492
# Branch Code_1021               0.011658  0.013858      0.013284    0.007442
# Branch Code_1022               0.007033  0.007416      0.012166    0.026445
# Branch Code_1023               0.014344  0.004609      0.001262    0.016154
# Branch Code_1024               0.016917  0.008096      0.010403    0.001376
# City_Bandung                   0.005927  0.001561      0.001951    0.014970
# City_Jakarta                   0.003823  0.003138      0.009902    0.010316
# City_Surabaya                  0.008455  0.004074      0.006892    0.021926
# Active Months                  0.054249  0.007048      0.293083    0.012810
# Age                            0.008340  0.000567      0.016806    0.002657
# Avg. Annual Income/Month       0.010524  0.004438      0.014371    0.009442
# Delta Balance                  1.000000  0.029989      0.288483    0.039949
# Diff PH                        0.029989  1.000000      0.003158    0.003760
# Mean Balance                   0.288483  0.003158      1.000000    0.054396
# Vintage_CR                     0.039949  0.003760      0.054396    1.000000
#
# [28 rows x 28 columns]

# %%
corrtest2
# Out:
#                           Branch Code_1001  Branch Code_1002  \
# Branch Code_1001                  1.000000          0.028917
# Branch Code_1002                  0.028917          1.000000
# Branch Code_1003                  0.028917          0.029128
# Branch Code_1004                  0.029673          0.029889
# Branch Code_1005                  0.029331          0.029545
# Branch Code_1006                  0.027640          0.027842
# Branch Code_1007                  0.028000          0.028204
# Branch Code_1008                  0.028214          0.028420
# Branch Code_1009                  0.028707          0.028917
# Branch Code_1011                  0.040203          0.040496
# Branch Code_1012                  0.039566          0.039855
# Branch Code_1013                  0.039353          0.039639
# Branch Code_1014                  0.038159          0.038437
# Branch Code_1015                  0.037440          0.037713
# Branch Code_1021                  0.064383          0.064852
# Branch Code_1022                  0.062555          0.063011
# Branch Code_1023                  0.063414          0.063876
# Branch Code_1024                  0.065268          0.065744
# City_Bandung                      0.098089          0.098804
# City_Jakarta                      0.292872          0.295007
# City_Surabaya                     0.168829          0.170060
# Active Months                     0.007562          0.011636
# Age                               0.010394          0.006371
# Avg. Annual Income/Month          0.003603          0.016078
# Delta Balance                     0.010657          0.001174
# Diff PH                           0.002625          0.000411
# Mean Balance                      0.009749          0.005640
# Vintage_CR                        0.020774          0.034256
#
#                           Branch Code_1003  Branch Code_1004  \
# Branch Code_1001                  0.028917          0.029673
# Branch Code_1002                  0.029128          0.029889
# Branch Code_1003                  1.000000          0.029889
# Branch Code_1004                  0.029889          1.000000
# Branch Code_1005                  0.029545          0.030318
# Branch Code_1006                  0.027842          0.028570
# Branch Code_1007                  0.028204          0.028941
# Branch Code_1008                  0.028420          0.029163
# Branch Code_1009                  0.028917          0.029673
# Branch Code_1011                  0.040496          0.041555
# Branch Code_1012                  0.039855          0.040897
# Branch Code_1013                  0.039639          0.040676
# Branch Code_1014                  0.038437          0.039442
# Branch Code_1015                  0.037713          0.038699
# Branch Code_1021                  0.064852          0.066548
# Branch Code_1022                  0.063011          0.064658
# Branch Code_1023                  0.063876          0.065546
# Branch Code_1024                  0.065744          0.067463
# City_Bandung                      0.098804          0.101388
# City_Jakarta                      0.295007          0.302721
# City_Surabaya                     0.170060          0.174506
# Active Months                     0.011636          0.007556
# Age                               0.013724          0.008420
# Avg. Annual Income/Month          0.001937          0.002095
# Delta Balance                     0.016142          0.023383
# Diff PH                           0.007450          0.007340
# Mean Balance                      0.001736          0.013205
# Vintage_CR                        0.021341          0.003376
#
#                           Branch Code_1005  Branch Code_1006  \
# Branch Code_1001                  0.029331          0.027640
# Branch Code_1002                  0.029545          0.027842
# Branch Code_1003                  0.029545          0.027842
# Branch Code_1004                  0.030318          0.028570
# Branch Code_1005                  1.000000          0.028241
# Branch Code_1006                  0.028241          1.000000
# Branch Code_1007                  0.028608          0.026959
# Branch Code_1008                  0.028827          0.027165
# Branch Code_1009                  0.029331          0.027640
# Branch Code_1011                  0.041076          0.038708
# Branch Code_1012                  0.040426          0.038095
# Branch Code_1013                  0.040208          0.037889
# Branch Code_1014                  0.038988          0.036740
# Branch Code_1015                  0.038253          0.036048
# Branch Code_1021                  0.065782          0.061989
# Branch Code_1022                  0.063914          0.060229
# Branch Code_1023                  0.064792          0.061056
# Branch Code_1024                  0.066686          0.062841
# City_Bandung                      0.100221          0.094442
# City_Jakarta                      0.299236          0.281983
# City_Surabaya                     0.172498          0.162551
# Active Months                     0.009181          0.002050
# Age                               0.001335          0.004534
# Avg. Annual Income/Month          0.008829          0.007488
# Delta Balance                     0.010614          0.007557
# Diff PH                           0.003334          0.002061
# Mean Balance                      0.007493          0.004017
# Vintage_CR                        0.002246          0.008669
#
#                           Branch Code_1007  Branch Code_1008  \
# Branch Code_1001                  0.028000          0.028214
# Branch Code_1002                  0.028204          0.028420
# Branch Code_1003                  0.028204          0.028420
# Branch Code_1004                  0.028941          0.029163
# Branch Code_1005                  0.028608          0.028827
# Branch Code_1006                  0.026959          0.027165
# Branch Code_1007                  1.000000          0.027518
# Branch Code_1008                  0.027518          1.000000
# Branch Code_1009                  0.028000          0.028214
# Branch Code_1011                  0.039212          0.039511
# Branch Code_1012                  0.038591          0.038886
# Branch Code_1013                  0.038383          0.038676
# Branch Code_1014                  0.037219          0.037503
# Branch Code_1015                  0.036517          0.036796
# Branch Code_1021                  0.062796          0.063276
# Branch Code_1022                  0.061013          0.061479
# Branch Code_1023                  0.061851          0.062323
# Branch Code_1024                  0.063659          0.064146
# City_Bandung                      0.095672          0.096403
# City_Jakarta                      0.285654          0.287836
# City_Surabaya                     0.164668          0.165926
# Active Months                     0.013401          0.005226
# Age                               0.011408          0.005992
# Avg. Annual Income/Month          0.024003          0.000678
# Delta Balance                     0.002299          0.009595
# Diff PH                           0.018009          0.012922
# Mean Balance                      0.006425          0.001792
# Vintage_CR                        0.003749          0.016428
#
#                           Branch Code_1009  Branch Code_1011  ...  \
# Branch Code_1001                  0.028707          0.040203  ...
# Branch Code_1002                  0.028917          0.040496  ...
# Branch Code_1003                  0.028917          0.040496  ...
# Branch Code_1004                  0.029673          0.041555  ...
# Branch Code_1005                  0.029331          0.041076  ...
# Branch Code_1006                  0.027640          0.038708  ...
# Branch Code_1007                  0.028000          0.039212  ...
# Branch Code_1008                  0.028214          0.039511  ...
# Branch Code_1009                  1.000000          0.040203  ...
# Branch Code_1011                  0.040203          1.000000  ...
# Branch Code_1012                  0.039566          0.055410  ...
# Branch Code_1013                  0.039353          0.055110  ...
# Branch Code_1014                  0.038159          0.053439  ...
# Branch Code_1015                  0.037440          0.052431  ...
# Branch Code_1021                  0.064383          0.090163  ...
# Branch Code_1022                  0.062555          0.087603  ...
# Branch Code_1023                  0.063414          0.088806  ...
# Branch Code_1024                  0.065268          0.091403  ...
# City_Bandung                      0.098089          0.409857  ...
# City_Jakarta                      0.292872          0.137270  ...
# City_Surabaya                     0.168829          0.236432  ...
# Active Months                     0.002926          0.002436  ...
# Age                               0.002933          0.011252  ...
# Avg. Annual Income/Month          0.012510          0.016018  ...
# Delta Balance                     0.002003          0.021118  ...
# Diff PH                           0.022414          0.012993  ...
# Mean Balance                      0.005889          0.005449  ...
# Vintage_CR                        0.014582          0.020666  ...
#
#                           City_Bandung  City_Jakarta  City_Surabaya  \
# Branch Code_1001              0.098089      0.292872       0.168829
# Branch Code_1002              0.098804      0.295007       0.170060
# Branch Code_1003              0.098804      0.295007       0.170060
# Branch Code_1004              0.101388      0.302721       0.174506
# Branch Code_1005              0.100221      0.299236       0.172498
# Branch Code_1006              0.094442      0.281983       0.162551
# Branch Code_1007              0.095672      0.285654       0.164668
# Branch Code_1008              0.096403      0.287836       0.165926
# Branch Code_1009              0.098089      0.292872       0.168829
# Branch Code_1011              0.409857      0.137270       0.236432
# Branch Code_1012              0.403370      0.135098       0.232690
# Branch Code_1013              0.401190      0.134367       0.231432
# Branch Code_1014              0.389024      0.130293       0.224414
# Branch Code_1015              0.381688      0.127836       0.220183
# Branch Code_1021              0.219987      0.219832       0.381349
# Branch Code_1022              0.213741      0.213590       0.370521
# Branch Code_1023              0.216676      0.216523       0.375609
# Branch Code_1024              0.223011      0.222855       0.386592
# City_Bandung                  1.000000      0.334922       0.576865
# City_Jakarta                  0.334922      1.000000       0.576459
# City_Surabaya                 0.576865      0.576459       1.000000
# Active Months                 0.012755      0.005472       0.006318
# Age                           0.018999      0.002929       0.013937
# Avg. Annual Income/Month      0.007774      0.000895       0.005966
# Delta Balance                 0.000073      0.004900       0.004185
# Diff PH                       0.013443      0.005620       0.006786
# Mean Balance                  0.001926      0.009918       0.006928
# Vintage_CR                    0.014970      0.010316       0.021926
#
#                           Active Months       Age  Avg. Annual Income/Month  \
# Branch Code_1001               0.007562  0.010394                  0.003603
# Branch Code_1002               0.011636  0.006371                  0.016078
# Branch Code_1003               0.011636  0.013724                  0.001937
# Branch Code_1004               0.007556  0.008420                  0.002095
# Branch Code_1005               0.009181  0.001335                  0.008829
# Branch Code_1006               0.002050  0.004534                  0.007488
# Branch Code_1007               0.013401  0.011408                  0.024003
# Branch Code_1008               0.005226  0.005992                  0.000678
# Branch Code_1009               0.002926  0.002933                  0.012510
# Branch Code_1011               0.002436  0.011252                  0.016018
# Branch Code_1012               0.008303  0.012025                  0.002862
# Branch Code_1013               0.010084  0.027836                  0.002401
# Branch Code_1014               0.020677  0.028956                  0.030870
# Branch Code_1015               0.005992  0.005162                  0.003849
# Branch Code_1021               0.012940  0.023573                  0.013912
# Branch Code_1022               0.000616  0.017031                  0.005639
# Branch Code_1023               0.003659  0.010069                  0.002502
# Branch Code_1024               0.018049  0.009204                  0.025677
# City_Bandung                   0.012755  0.018999                  0.007774
# City_Jakarta                   0.005472  0.002929                  0.000895
# City_Surabaya                  0.006318  0.013937                  0.005966
# Active Months                  1.000000  0.018712                  0.015891
# Age                            0.018712  1.000000                  0.158954
# Avg. Annual Income/Month       0.015891  0.158954                  1.000000
# Delta Balance                  0.083674  0.000706                  0.011159
# Diff PH                        0.001956  0.008278                  0.011563
# Mean Balance                   0.255592  0.016865                  0.014347
# Vintage_CR                     0.004071  0.002657                  0.009442
#
#                           Delta Balance   Diff PH  Mean Balance  Vintage_CR
# Branch Code_1001               0.010657  0.002625      0.009749    0.020774
# Branch Code_1002               0.001174  0.000411      0.005640    0.034256
# Branch Code_1003               0.016142  0.007450      0.001736    0.021341
# Branch Code_1004               0.023383  0.007340      0.013205    0.003376
# Branch Code_1005               0.010614  0.003334      0.007493    0.002246
# Branch Code_1006               0.007557  0.002061      0.004017    0.008669
# Branch Code_1007               0.002299  0.018009      0.006425    0.003749
# Branch Code_1008               0.009595  0.012922      0.001792    0.016428
# Branch Code_1009               0.002003  0.022414      0.005889    0.014582
# Branch Code_1011               0.021118  0.012993      0.005449    0.020666
# Branch Code_1012               0.013924  0.032104      0.009265    0.007458
# Branch Code_1013               0.004551  0.016124      0.006893    0.005006
# Branch Code_1014               0.006760  0.016468      0.005964    0.021498
# Branch Code_1015               0.005612  0.013690      0.013243    0.010492
# Branch Code_1021               0.017532  0.016359      0.013330    0.007442
# Branch Code_1022               0.001312  0.010089      0.012155    0.026445
# Branch Code_1023               0.005585  0.002850      0.001311    0.016154
# Branch Code_1024               0.019397  0.013060      0.010465    0.001376
# City_Bandung                   0.000073  0.013443      0.001926    0.014970
# City_Jakarta                   0.004900  0.005620      0.009918    0.010316
# City_Surabaya                  0.004185  0.006786      0.006928    0.021926
# Active Months                  0.083674  0.001956      0.255592    0.004071
# Age                            0.000706  0.008278      0.016865    0.002657
# Avg. Annual Income/Month       0.011159  0.011563      0.014347    0.009442
# Delta Balance                  1.000000  0.029605      0.197002    0.031879
# Diff PH                        0.029605  1.000000      0.010175    0.000111
# Mean Balance                   0.197002  0.010175      1.000000    0.054320
# Vintage_CR                     0.031879  0.000111      0.054320    1.000000
#
# [28 rows x 28 columns]

# %%
#Membuang nilai redundan pada matriks
upper1 = corrtest1.where(np.triu(np.ones(corrtest1.shape), k=1).astype(bool))
upper2 = corrtest2.where(np.triu(np.ones(corrtest1.shape), k=1).astype(bool))

#Mencari nilai yang berkorelasi di atas 0.7
to_drop1 = [column for column in upper1.columns if any(upper1[column] > 0.7)]
to_drop2 = [column for column in upper2.columns if any(upper2[column] > 0.7)]

#menghapus kolom yang korelasinya >0.7
X1 = X1.drop(to_drop1, axis=1)
X2 = X2.drop(to_drop2, axis=1)

# %%
X1_val = X1_val.drop(to_drop1, axis=1)
X2_val = X2_val.drop(to_drop2, axis=1)

# %%
X1_val
# Out:
#       Branch Code_1001  Branch Code_1002  Branch Code_1003  Branch Code_1004  \
# 0                 True             False             False             False
# 1                False             False             False             False
# 2                False             False             False             False
# 3                False             False             False             False
# 4                False             False             False             False
# ...                ...               ...               ...               ...
# 7556             False             False             False             False
# 7557             False             False             False             False
# 7558             False             False             False             False
# 7559             False             False             False             False
# 7560             False             False             False             False
#
#       Branch Code_1005  Branch Code_1006  Branch Code_1007  Branch Code_1008  \
# 0                False             False             False             False
# 1                 True             False             False             False
# 2                False             False             False             False
# 3                False             False             False              True
# 4                False             False             False             False
# ...                ...               ...               ...               ...
# 7556             False             False             False             False
# 7557             False             False             False             False
# 7558             False             False             False             False
# 7559             False             False             False             False
# 7560             False             False             False             False
#
#       Branch Code_1009  Branch Code_1011  ...  City_Bandung  City_Jakarta  \
# 0                False             False  ...         False          True
# 1                False             False  ...         False          True
# 2                 True             False  ...         False          True
# 3                False             False  ...         False          True
# 4                 True             False  ...         False          True
# ...                ...               ...  ...           ...           ...
# 7556             False             False  ...         False         False
# 7557             False             False  ...         False         False
# 7558             False             False  ...         False         False
# 7559             False             False  ...         False         False
# 7560             False             False  ...         False         False
#
#       City_Surabaya  Active Months       Age  Avg. Annual Income/Month  \
# 0             False      -0.135176 -1.185374                  0.663649
# 1             False      -1.013239  1.580668                 -0.680854
# 2             False      -1.013239 -1.469071                 -1.101011
# 3             False      -1.013239 -0.263360                 -0.512791
# 4             False      -0.135176 -0.192436                  0.327524
# ...             ...            ...       ...                       ...
# 7556           True       0.742887 -0.901678                 -0.764885
# 7557           True      -1.891303  0.658654                 -0.596822
# 7558           True      -1.891303  0.162185                 -0.596822
# 7559           True       1.620951  1.651592                 -0.428759
# 7560           True      -0.135176 -0.617981                 -0.008602
#
#       Delta Balance   Diff PH  Mean Balance  Vintage_CR
# 0          1.964593 -0.531491     -0.947970    0.296502
# 1         -0.319523 -0.531491     -0.953281    0.296502
# 2          2.281673 -0.531491     -0.947232    0.296502
# 3         -0.319523 -0.531491     -0.953281    0.296502
# 4          0.510182 -0.531491     -0.948314    0.296502
# ...             ...       ...           ...         ...
# 7556      -0.676360 -0.531491     -0.414767    0.296502
# 7557      -0.319523 -0.531491      2.063446    0.296502
# 7558      -0.319523 -0.531491     -0.953281    0.296502
# 7559      -0.348307 -0.531491     -0.275996    0.296502
# 7560       0.816033  1.520912     -0.101607    0.296502
#
# [7561 rows x 28 columns]

# %% [markdown]
# ##**Train test data splitting**

# %%
y1.value_counts()
y2.value_counts()
# Out:
# Unpaid Tagging
# 0    5542
# 1    2019
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.3, stratify=y1, random_state=30)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.3, stratify=y2, random_state=30)

# %% [markdown]
# #**Modelling**

# %% [markdown]
# 3 algoritma:
#
# 1. Logistic Regression
# 2. Gradient Boosting
# 3. Random Forest

# %% [markdown]
# ##**Logistic Regression**

# %%
penalty = ['l1'] # Changed from ['12'] to ['l1', 'l2'] to provide valid penalty options
tol = [0.001, 0.0001, 0.00001]
C = [100.0, 10.0, 1.00, 0.1, 0.001]
fit_intercept = [True, False]
intercept_scaling = [1.0, 0.75, 0.5, 0.25]
class_weight = ['balanced', None]
solver = ['newton-cg', 'sag', 'lbfgs', 'saga']
max_iter = [14000]
param_distribution = dict(penalty=penalty, tol=tol, fit_intercept=fit_intercept,
                           intercept_scaling=intercept_scaling, class_weight=class_weight,
                            solver=solver, max_iter = max_iter)

# %%
from sklearn.model_selection import GridSearchCV

# %%
import time
#cross validation
logreg = LogisticRegression()
grid = GridSearchCV(estimator=logreg, param_grid=param_distribution,
        scoring = 'recall', cv=5, n_jobs=-1)

start_time = time.time()
grid_result = grid.fit(X1_train, y1_train)
#Summarize results
print('Best: %f using %s' %(grid_result.best_score_, grid_result.best_params_))
print('Execution time: ' + str((time.time() - start_time)) + ' s')
# Out:
# Best: 0.411906 using {'class_weight': 'balanced', 'fit_intercept': True, 'intercept_scaling': 1.0, 'max_iter': 14000, 'penalty': 'l1', 'solver': 'saga', 'tol': 0.001}
# Execution time: 67.8443374633789 s
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 720 fits failed out of a total of 960.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.41190637 0.41119966 0.41119966
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.41119966 0.41119966 0.41119966
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.41119966 0.41119966 0.41119966
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.41119966 0.41119966 0.41119966
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.41049044 0.41049044 0.41049044
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.41049044 0.41049044 0.41049044
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.41049044 0.41049044 0.41049044
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.41049044 0.41049044 0.41049044
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426]
#   warnings.warn(

# %%
#cross validation
logreg = LogisticRegression()
grid2 = GridSearchCV(estimator=logreg, param_grid=param_distribution,
        scoring = 'recall', cv=5, n_jobs=-1)

start_time = time.time()
grid_result = grid2.fit(X2_train, y2_train)
#Summarize results
print('Best: %f using %s' %(grid_result.best_score_, grid_result.best_params_))
print('Execution time: ' + str((time.time() - start.time)) + ' s')
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 720 fits failed out of a total of 960.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.38359522 0.38359522 0.38359522
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.38359522 0.38359522 0.38359522
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.38359522 0.38359522 0.38359522
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.38359522 0.38359522 0.38359522
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.382886   0.382886   0.382886
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.382886   0.382886   0.382886
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.382886   0.382886   0.382886
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.382886   0.382886   0.382886
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.29866426 0.29866426 0.29866426]
#   warnings.warn(
# Best: 0.383595 using {'class_weight': 'balanced', 'fit_intercept': True, 'intercept_scaling': 1.0, 'max_iter': 14000, 'penalty': 'l1', 'solver': 'saga', 'tol': 0.001}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-356-2ac3603508c6> in <cell line: 0>()
#       8 #Summarize results
#       9 print('Best: %f using %s' %(grid_result.best_score_, grid_result.best_params_))
# ---> 10 print('Execution time: ' + str((time.time() - start.time)) + ' s')
#
# NameError: name 'start' is not defined
